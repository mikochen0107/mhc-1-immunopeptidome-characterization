# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If you imported a project with a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# There's no requirements.txt, so nothing to install. This is the case with most projects.

# %%
# %%bash
# # If you have previously installed any packages into this project, we re-install them here to restore your environment.
# if test -f .deepnote/requirements.txt
#   then
#     sed -i '/jupyter/d' .deepnote/requirements.txt
#     pip install -r .deepnote/requirements.txt
#   else echo "Seems like there is nothing to restore. Most likely, you haven't installed any extra packages so far."
# fi
# Out:
# Requirement already satisfied: attrs==19.3.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 1)) (19.3.0)
# Requirement already satisfied: backcall==0.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: bleach==3.1.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 3)) (3.1.5)
# Collecting certifi==2020.4.5.2
#   Downloading certifi-2020.4.5.2-py2.py3-none-any.whl (157 kB)
# Requirement already satisfied: chardet==3.0.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 5)) (3.0.4)
# Requirement already satisfied: cycler==0.10.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: decorator==4.4.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 7)) (4.4.2)
# Requirement already satisfied: defusedxml==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 8)) (0.6.0)
# Requirement already satisfied: docopt==0.6.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 9)) (0.6.2)
# Requirement already satisfied: entrypoints==0.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 10)) (0.3)
# Collecting idna==2.9
#   Downloading idna-2.9-py2.py3-none-any.whl (58 kB)
# Collecting importlib-metadata==1.6.1
#   Downloading importlib_metadata-1.6.1-py2.py3-none-any.whl (31 kB)
# Collecting ipykernel==5.3.0
#   Downloading ipykernel-5.3.0-py3-none-any.whl (119 kB)
# Collecting ipython==7.15.0
#   Downloading ipython-7.15.0-py3-none-any.whl (783 kB)
# Requirement already satisfied: ipython-genutils==0.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 15)) (0.2.0)
# Requirement already satisfied: ipywidgets==7.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 16)) (7.5.1)
# Collecting jedi==0.17.0
#   Downloading jedi-0.17.0-py2.py3-none-any.whl (1.1 MB)
# Requirement already satisfied: Jinja2==2.11.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 18)) (2.11.2)
# Collecting joblib==0.15.1
#   Downloading joblib-0.15.1-py3-none-any.whl (298 kB)
# Requirement already satisfied: jsonschema==3.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 20)) (3.2.0)
# Requirement already satisfied: kiwisolver==1.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 21)) (1.2.0)
# Requirement already satisfied: MarkupSafe==1.1.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 22)) (1.1.1)
# Requirement already satisfied: mistune==0.8.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 23)) (0.8.4)
# Requirement already satisfied: nbconvert==5.6.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 24)) (5.6.1)
# Requirement already satisfied: nbformat==5.0.7 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 25)) (5.0.7)
# Collecting numpy==1.18.5
#   Downloading numpy-1.18.5-cp37-cp37m-manylinux1_x86_64.whl (20.1 MB)
# Requirement already satisfied: packaging==20.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 27)) (20.4)
# Requirement already satisfied: pandas==0.25.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 28)) (0.25.0)
# Requirement already satisfied: pandocfilters==1.4.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 29)) (1.4.2)
# Requirement already satisfied: parso==0.7.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 30)) (0.7.0)
# Requirement already satisfied: pexpect==4.8.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 31)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 32)) (0.7.5)
# Requirement already satisfied: pipreqs@ git+https://github.com/deepnote/pipreqs.git@5c94fac42a8ddd19eabd75e3de8e84bb8120afd1 from git+https://github.com/deepnote/pipreqs.git@5c94fac42a8ddd19eabd75e3de8e84bb8120afd1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 33)) (0.4.8)
# Requirement already satisfied: pluggy==1.0.0.dev0 in /opt/venv/lib/python3.7/site-packages/pluggy-1.0.0.dev0-py3.7.egg (from -r .deepnote/requirements.txt (line 34)) (1.0.0.dev0)
# Requirement already satisfied: prometheus-client==0.8.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 35)) (0.8.0)
# Requirement already satisfied: prompt-toolkit==3.0.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 36)) (3.0.5)
# Requirement already satisfied: ptyprocess==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 37)) (0.6.0)
# Requirement already satisfied: Pygments==2.6.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 38)) (2.6.1)
# Requirement already satisfied: pyparsing==2.4.7 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 39)) (2.4.7)
# Requirement already satisfied: pyrsistent==0.16.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 40)) (0.16.0)
# Requirement already satisfied: python-dateutil==2.8.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 41)) (2.8.1)
# Requirement already satisfied: python-jsonrpc-server==0.3.4 in /opt/venv/lib/python3.7/site-packages/python_jsonrpc_server-0.3.4-py3.7.egg (from -r .deepnote/requirements.txt (line 42)) (0.3.4)
# Requirement already satisfied: python-language-server==0.30.0+39.g60b5005 in /opt/venv/lib/python3.7/site-packages/python_language_server-0.30.0+39.g60b5005-py3.7.egg (from -r .deepnote/requirements.txt (line 43)) (0.30.0+39.g60b5005)
# Requirement already satisfied: pytz==2020.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 44)) (2020.1)
# Requirement already satisfied: pyzmq==19.0.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 45)) (19.0.1)
# Requirement already satisfied: requests==2.24.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 46)) (2.24.0)
# Requirement already satisfied: scikit-learn==0.23.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 47)) (0.23.1)
# Requirement already satisfied: scipy==1.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 48)) (1.5.1)
# Requirement already satisfied: Send2Trash==1.5.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 49)) (1.5.0)
# Requirement already satisfied: six==1.15.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 50)) (1.15.0)
# Requirement already satisfied: terminado==0.8.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 51)) (0.8.3)
# Requirement already satisfied: testpath==0.4.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 52)) (0.4.4)
# Requirement already satisfied: threadpoolctl==2.1.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 53)) (2.1.0)
# Requirement already satisfied: tornado==6.0.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 54)) (6.0.4)
# Requirement already satisfied: traitlets==4.3.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 55)) (4.3.3)
# Requirement already satisfied: ujson==1.35 in /opt/venv/lib/python3.7/site-packages/ujson-1.35-py3.7-linux-x86_64.egg (from -r .deepnote/requirements.txt (line 56)) (1.35)
# Requirement already satisfied: urllib3==1.25.9 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 57)) (1.25.9)
# Requirement already satisfied: wcwidth==0.2.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 58)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 59)) (0.5.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 60)) (3.5.1)
# Requirement already satisfied: yarg==0.1.9 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 61)) (0.1.9)
# Requirement already satisfied: zipp==3.1.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 62)) (3.1.0)
# Requirement already satisfied: jupyter-client in /opt/venv/lib/python3.7/site-packages (from ipykernel==5.3.0->-r .deepnote/requirements.txt (line 13)) (6.1.5)
# Requirement already satisfied: setuptools>=18.5 in /opt/venv/lib/python3.7/site-packages (from ipython==7.15.0->-r .deepnote/requirements.txt (line 14)) (47.3.1)
# Requirement already satisfied: jupyter-core in /opt/venv/lib/python3.7/site-packages (from nbconvert==5.6.1->-r .deepnote/requirements.txt (line 24)) (4.6.3)
# Requirement already satisfied: notebook>=4.4.1 in /opt/venv/lib/python3.7/site-packages (from widgetsnbextension==3.5.1->-r .deepnote/requirements.txt (line 60)) (7.0.0.dev0)
# Installing collected packages: certifi, idna, importlib-metadata, jedi, ipython, ipykernel, joblib, numpy
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2020.6.20
#     Uninstalling certifi-2020.6.20:
#       Successfully uninstalled certifi-2020.6.20
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 1.7.0
#     Uninstalling importlib-metadata-1.7.0:
#       Successfully uninstalled importlib-metadata-1.7.0
#   Attempting uninstall: jedi
#     Found existing installation: jedi 0.17.1
#     Uninstalling jedi-0.17.1:
#       Successfully uninstalled jedi-0.17.1
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.16.1
#     Uninstalling ipython-7.16.1:
#       Successfully uninstalled ipython-7.16.1
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.3.1
#     Uninstalling ipykernel-5.3.1:
#       Successfully uninstalled ipykernel-5.3.1
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.16.0
#     Uninstalling joblib-0.16.0:
#       Successfully uninstalled joblib-0.16.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.0
#     Uninstalling numpy-1.19.0:
#       Successfully uninstalled numpy-1.19.0
# Successfully installed certifi-2020.4.5.2 idna-2.9 importlib-metadata-1.6.1 ipykernel-5.3.0 ipython-7.15.0 jedi-0.17.0 joblib-0.15.1 numpy-1.18.5

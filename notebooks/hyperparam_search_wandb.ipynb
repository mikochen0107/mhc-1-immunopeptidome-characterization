# %%
import os
import sys
sys.path.append("..")  # add top folder to path

import impepdom

# %%
# !pip install wandb
# Out:
# ...
#      |████████████████████████████████| 1.4 MB 3.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 269 kB 15.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 97 kB 2.6 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 451 kB 18.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 82 kB 554 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 107 kB 23.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 449 kB 24.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 94 kB 1.9 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 70 kB 5.2 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 63 kB 1.2 MB/s  eta 0:00:01
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44619 sha256=066e1e72e2d1ad9916c257d89afb570cadd4e2eeadead2dab4f3cc64e2964323
#   Stored in directory: /home/jovyan/.cache/pip/wheels/5e/03/1e/e1e954795d6f35dfc7b637fe2277bff021303bd9570ecea653
# ...
